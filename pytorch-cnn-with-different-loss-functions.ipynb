# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/mnist-in-csv/mnist_test.csv
# /kaggle/input/mnist-in-csv/mnist_train.csv

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt

# %%
class CSVDataset(Dataset):
    def __init__(self, csv_file):
        df = pd.read_csv(csv_file)
        self.data = df[(df['label'] ==5) | (df['label'] ==6) | (df['label'] ==7) | (df['label'] ==0) | (df['label'] ==2)]
        self.X = self.data.iloc[:, 1:].values
        self.X = self.X.reshape(-1,1, 28, 28).astype(np.float32)/255
        label_map = {0: 0, 2: 1, 5: 2, 6: 3, 7: 4}
        self.y = self.data['label'].map(label_map).values
        #self.y = self.data.iloc[:, -1].values
        

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        x = torch.tensor(self.X[idx], dtype=torch.float32)
        y=torch.tensor(self.y[idx], dtype=torch.long)
        return x, y

# %%
train_dataset = CSVDataset('/kaggle/input/mnist-in-csv/mnist_train.csv')
test_dataset = CSVDataset('/kaggle/input/mnist-in-csv/mnist_test.csv')
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=True)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
class CNN(nn.Module):
    def __init__(self, num_classes=5):
        super(CNN, self).__init__()

        self.conv1 = nn.Conv2d(in_channels=1, out_channels=32, kernel_size=3, stride=1, padding=1)
        self.bn1 = nn.BatchNorm2d(32)
        
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1)
        self.bn2 = nn.BatchNorm2d(64)

        self.pool = nn.MaxPool2d(kernel_size=2, stride=2)


        self.fc1 = nn.Linear(64 * 7 * 7, 128)
        self.fc2 = nn.Linear(128, num_classes)

    def forward(self, x):
        x= self.pool(F.relu(self.bn1(self.conv1(x))))
        x = self.pool(F.relu(self.bn2(self.conv2(x))))

        x = x.view(x.size(0), -1)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# %%
def model_training(model, optimizer, criterion, epochs=50):
    train_losses, test_losses = [], []
    train_accuracies, test_accuracies = [],[]

    for epoch in range(epochs):
        model.train()
        total_train_loss = 0
        total_train = 0
        correct_train = 0

        for images, labels in train_loader:
            images, labels = images.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            total_train_loss += loss.item()

            value, predicted = torch.max(outputs.data, 1)
            correct_train += (predicted==labels).sum().item()
            total_train += labels.size(0)

        avg_train_loss = total_train_loss/len(train_loader)
        train_accuracy = correct_train/total_train
        train_losses.append(avg_train_loss)
        train_accuracies.append(train_accuracy)

        model.eval()
        total_test_loss = 0
        correct_test = 0
        total_test = 0
        with torch.no_grad():
            for images, labels in test_loader:
                images, labels = images.to(device), labels.to(device)
                outputs = model(images)
                loss = criterion(outputs, labels)
                total_test_loss += loss.item()

                _, predicted = torch.max(outputs.data, 1)
                correct_test+=(predicted==labels).sum().item()
                total_test +=labels.size(0)

        avg_test_loss = total_test_loss / len(test_loader)
        test_accuracy = correct_test / total_test
        test_losses.append(avg_test_loss)
        test_accuracies.append(test_accuracy)
    
        print(f"Epoch {epoch+1}/{epochs} | "
                  f"Train Loss: {avg_train_loss:.4f}, Train Acc: {train_accuracy*100:.2f}% | "
                  f"Test Loss: {avg_test_loss:.4f}, Test Acc: {test_accuracy*100:.2f}%")

                
    return train_losses, test_losses, train_accuracies, test_accuracies

# %%
model = CNN().to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.00001)

# %%
train_losses_ce, test_losses_ce, train_acc_ce, test_acc_ce = model_training(model, optimizer, criterion)
# Out:
# Epoch 1/50 | Train Loss: 0.4226, Train Acc: 92.24% | Test Loss: 0.1416, Test Acc: 96.81%
# Epoch 2/50 | Train Loss: 0.0974, Train Acc: 97.65% | Test Loss: 0.0791, Test Acc: 97.91%
# Epoch 3/50 | Train Loss: 0.0597, Train Acc: 98.49% | Test Loss: 0.0574, Test Acc: 98.32%
# Epoch 4/50 | Train Loss: 0.0432, Train Acc: 98.86% | Test Loss: 0.0455, Test Acc: 98.53%
# Epoch 5/50 | Train Loss: 0.0335, Train Acc: 99.14% | Test Loss: 0.0382, Test Acc: 98.67%
# Epoch 6/50 | Train Loss: 0.0281, Train Acc: 99.29% | Test Loss: 0.0343, Test Acc: 98.90%
# Epoch 7/50 | Train Loss: 0.0237, Train Acc: 99.39% | Test Loss: 0.0308, Test Acc: 98.98%
# Epoch 8/50 | Train Loss: 0.0205, Train Acc: 99.48% | Test Loss: 0.0290, Test Acc: 99.06%
# Epoch 9/50 | Train Loss: 0.0179, Train Acc: 99.54% | Test Loss: 0.0288, Test Acc: 98.98%
# Epoch 10/50 | Train Loss: 0.0163, Train Acc: 99.59% | Test Loss: 0.0260, Test Acc: 99.06%
# Epoch 11/50 | Train Loss: 0.0147, Train Acc: 99.61% | Test Loss: 0.0260, Test Acc: 99.10%
# Epoch 12/50 | Train Loss: 0.0132, Train Acc: 99.69% | Test Loss: 0.0252, Test Acc: 99.16%
# Epoch 13/50 | Train Loss: 0.0120, Train Acc: 99.72% | Test Loss: 0.0248, Test Acc: 99.20%
# Epoch 14/50 | Train Loss: 0.0110, Train Acc: 99.76% | Test Loss: 0.0243, Test Acc: 99.22%
# Epoch 15/50 | Train Loss: 0.0100, Train Acc: 99.76% | Test Loss: 0.0227, Test Acc: 99.28%
# Epoch 16/50 | Train Loss: 0.0093, Train Acc: 99.80% | Test Loss: 0.0234, Test Acc: 99.24%
# Epoch 17/50 | Train Loss: 0.0084, Train Acc: 99.81% | Test Loss: 0.0243, Test Acc: 99.18%
# Epoch 18/50 | Train Loss: 0.0079, Train Acc: 99.82% | Test Loss: 0.0234, Test Acc: 99.26%
# Epoch 19/50 | Train Loss: 0.0069, Train Acc: 99.89% | Test Loss: 0.0227, Test Acc: 99.28%
# Epoch 20/50 | Train Loss: 0.0065, Train Acc: 99.87% | Test Loss: 0.0245, Test Acc: 99.22%
# Epoch 21/50 | Train Loss: 0.0060, Train Acc: 99.92% | Test Loss: 0.0241, Test Acc: 99.28%
# Epoch 22/50 | Train Loss: 0.0056, Train Acc: 99.93% | Test Loss: 0.0232, Test Acc: 99.24%
# Epoch 23/50 | Train Loss: 0.0052, Train Acc: 99.91% | Test Loss: 0.0247, Test Acc: 99.24%
# Epoch 24/50 | Train Loss: 0.0046, Train Acc: 99.94% | Test Loss: 0.0235, Test Acc: 99.30%
# Epoch 25/50 | Train Loss: 0.0044, Train Acc: 99.95% | Test Loss: 0.0239, Test Acc: 99.28%
# Epoch 26/50 | Train Loss: 0.0038, Train Acc: 99.97% | Test Loss: 0.0243, Test Acc: 99.24%
# Epoch 27/50 | Train Loss: 0.0036, Train Acc: 99.97% | Test Loss: 0.0248, Test Acc: 99.22%
# Epoch 28/50 | Train Loss: 0.0033, Train Acc: 99.97% | Test Loss: 0.0244, Test Acc: 99.26%
# Epoch 29/50 | Train Loss: 0.0029, Train Acc: 99.98% | Test Loss: 0.0277, Test Acc: 99.16%
# Epoch 30/50 | Train Loss: 0.0028, Train Acc: 99.98% | Test Loss: 0.0243, Test Acc: 99.35%
# Epoch 31/50 | Train Loss: 0.0025, Train Acc: 99.98% | Test Loss: 0.0254, Test Acc: 99.26%
# Epoch 32/50 | Train Loss: 0.0022, Train Acc: 99.99% | Test Loss: 0.0247, Test Acc: 99.30%
# Epoch 33/50 | Train Loss: 0.0021, Train Acc: 99.99% | Test Loss: 0.0257, Test Acc: 99.26%
# Epoch 34/50 | Train Loss: 0.0018, Train Acc: 99.99% | Test Loss: 0.0271, Test Acc: 99.24%
# Epoch 35/50 | Train Loss: 0.0016, Train Acc: 100.00% | Test Loss: 0.0258, Test Acc: 99.26%
# Epoch 36/50 | Train Loss: 0.0015, Train Acc: 100.00% | Test Loss: 0.0268, Test Acc: 99.26%
# Epoch 37/50 | Train Loss: 0.0014, Train Acc: 100.00% | Test Loss: 0.0266, Test Acc: 99.26%
# Epoch 38/50 | Train Loss: 0.0014, Train Acc: 99.99% | Test Loss: 0.0265, Test Acc: 99.30%
# Epoch 39/50 | Train Loss: 0.0011, Train Acc: 100.00% | Test Loss: 0.0263, Test Acc: 99.33%
# Epoch 40/50 | Train Loss: 0.0010, Train Acc: 100.00% | Test Loss: 0.0278, Test Acc: 99.26%
# Epoch 41/50 | Train Loss: 0.0009, Train Acc: 100.00% | Test Loss: 0.0277, Test Acc: 99.30%
# Epoch 42/50 | Train Loss: 0.0009, Train Acc: 100.00% | Test Loss: 0.0268, Test Acc: 99.35%
# Epoch 43/50 | Train Loss: 0.0007, Train Acc: 100.00% | Test Loss: 0.0273, Test Acc: 99.26%
# Epoch 44/50 | Train Loss: 0.0007, Train Acc: 100.00% | Test Loss: 0.0285, Test Acc: 99.33%
# Epoch 45/50 | Train Loss: 0.0006, Train Acc: 100.00% | Test Loss: 0.0286, Test Acc: 99.35%
# Epoch 46/50 | Train Loss: 0.0005, Train Acc: 100.00% | Test Loss: 0.0303, Test Acc: 99.26%
# Epoch 47/50 | Train Loss: 0.0005, Train Acc: 100.00% | Test Loss: 0.0296, Test Acc: 99.28%
# Epoch 48/50 | Train Loss: 0.0004, Train Acc: 100.00% | Test Loss: 0.0300, Test Acc: 99.24%
# Epoch 49/50 | Train Loss: 0.0004, Train Acc: 100.00% | Test Loss: 0.0296, Test Acc: 99.33%
# Epoch 50/50 | Train Loss: 0.0003, Train Acc: 100.00% | Test Loss: 0.0305, Test Acc: 99.35%

# %%
def model_training_MSE(model, optimizer, criterion, epochs=50):
    train_losses, test_losses = [], []
    train_accuracies, test_accuracies = [],[]

    for epoch in range(epochs):
        model.train()
        total_train_loss = 0
        total_train = 0
        correct_train = 0

        for images, labels in train_loader:
            images, labels = images.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(images)
            labels_one_hot = F.one_hot(labels, num_classes=5).float()
            loss = criterion(outputs, labels_one_hot)
            loss.backward()
            optimizer.step()
            total_train_loss += loss.item()

            value, predicted = torch.max(outputs.data, 1)
            correct_train += (predicted==labels).sum().item()
            total_train += labels.size(0)

        avg_train_loss = total_train_loss/len(train_loader)
        train_accuracy = correct_train/total_train
        train_losses.append(avg_train_loss)
        train_accuracies.append(train_accuracy)

        model.eval()
        total_test_loss = 0
        correct_test = 0
        total_test = 0
        with torch.no_grad():
            for images, labels in test_loader:
                images, labels = images.to(device), labels.to(device)
                outputs = model(images)
                labels_one_hot = F.one_hot(labels, num_classes=5).float()
                loss = criterion(outputs, labels_one_hot)
                total_test_loss += loss.item()

                _, predicted = torch.max(outputs.data, 1)
                correct_test+=(predicted==labels).sum().item()
                total_test +=labels.size(0)

        avg_test_loss = total_test_loss / len(test_loader)
        test_accuracy = correct_test / total_test
        test_losses.append(avg_test_loss)
        test_accuracies.append(test_accuracy)
    
        print(f"Epoch {epoch+1}/{epochs} | "
                  f"Train Loss: {avg_train_loss:.4f}, Train Acc: {train_accuracy*100:.2f}% | "
                  f"Test Loss: {avg_test_loss:.4f}, Test Acc: {test_accuracy*100:.2f}%")

                
    return train_losses, test_losses, train_accuracies, test_accuracies

# %%
model2 = CNN().to(device)
criterion = nn.MSELoss()
optimizer = optim.Adam(model2.parameters(), lr=0.00001)

# %%
train_losses_mse, test_losses_mse, train_acc_mse, test_acc_mse = model_training_MSE(model2, optimizer, criterion)
# Out:
# Epoch 1/50 | Train Loss: 0.0422, Train Acc: 92.55% | Test Loss: 0.0218, Test Acc: 98.04%
# Epoch 2/50 | Train Loss: 0.0182, Train Acc: 98.54% | Test Loss: 0.0157, Test Acc: 98.59%
# Epoch 3/50 | Train Loss: 0.0136, Train Acc: 99.01% | Test Loss: 0.0125, Test Acc: 98.79%
# Epoch 4/50 | Train Loss: 0.0111, Train Acc: 99.24% | Test Loss: 0.0108, Test Acc: 98.94%
# Epoch 5/50 | Train Loss: 0.0095, Train Acc: 99.33% | Test Loss: 0.0096, Test Acc: 99.04%
# Epoch 6/50 | Train Loss: 0.0083, Train Acc: 99.43% | Test Loss: 0.0090, Test Acc: 99.12%
# Epoch 7/50 | Train Loss: 0.0075, Train Acc: 99.50% | Test Loss: 0.0079, Test Acc: 99.20%
# Epoch 8/50 | Train Loss: 0.0068, Train Acc: 99.54% | Test Loss: 0.0074, Test Acc: 99.20%
# Epoch 9/50 | Train Loss: 0.0062, Train Acc: 99.57% | Test Loss: 0.0070, Test Acc: 99.20%
# Epoch 10/50 | Train Loss: 0.0057, Train Acc: 99.61% | Test Loss: 0.0067, Test Acc: 99.28%
# Epoch 11/50 | Train Loss: 0.0054, Train Acc: 99.64% | Test Loss: 0.0063, Test Acc: 99.30%
# Epoch 12/50 | Train Loss: 0.0050, Train Acc: 99.66% | Test Loss: 0.0060, Test Acc: 99.35%
# Epoch 13/50 | Train Loss: 0.0047, Train Acc: 99.66% | Test Loss: 0.0058, Test Acc: 99.37%
# Epoch 14/50 | Train Loss: 0.0045, Train Acc: 99.69% | Test Loss: 0.0057, Test Acc: 99.33%
# Epoch 15/50 | Train Loss: 0.0042, Train Acc: 99.73% | Test Loss: 0.0055, Test Acc: 99.41%
# Epoch 16/50 | Train Loss: 0.0040, Train Acc: 99.75% | Test Loss: 0.0054, Test Acc: 99.41%
# Epoch 17/50 | Train Loss: 0.0038, Train Acc: 99.75% | Test Loss: 0.0053, Test Acc: 99.41%
# Epoch 18/50 | Train Loss: 0.0037, Train Acc: 99.77% | Test Loss: 0.0049, Test Acc: 99.41%
# Epoch 19/50 | Train Loss: 0.0035, Train Acc: 99.80% | Test Loss: 0.0049, Test Acc: 99.41%
# Epoch 20/50 | Train Loss: 0.0034, Train Acc: 99.81% | Test Loss: 0.0048, Test Acc: 99.37%
# Epoch 21/50 | Train Loss: 0.0032, Train Acc: 99.82% | Test Loss: 0.0047, Test Acc: 99.45%
# Epoch 22/50 | Train Loss: 0.0031, Train Acc: 99.83% | Test Loss: 0.0048, Test Acc: 99.47%
# Epoch 23/50 | Train Loss: 0.0030, Train Acc: 99.83% | Test Loss: 0.0046, Test Acc: 99.41%
# Epoch 24/50 | Train Loss: 0.0029, Train Acc: 99.85% | Test Loss: 0.0046, Test Acc: 99.45%
# Epoch 25/50 | Train Loss: 0.0028, Train Acc: 99.86% | Test Loss: 0.0045, Test Acc: 99.45%
# Epoch 26/50 | Train Loss: 0.0027, Train Acc: 99.87% | Test Loss: 0.0043, Test Acc: 99.41%
# Epoch 27/50 | Train Loss: 0.0026, Train Acc: 99.88% | Test Loss: 0.0042, Test Acc: 99.43%
# Epoch 28/50 | Train Loss: 0.0025, Train Acc: 99.89% | Test Loss: 0.0043, Test Acc: 99.45%
# Epoch 29/50 | Train Loss: 0.0025, Train Acc: 99.89% | Test Loss: 0.0043, Test Acc: 99.43%
# Epoch 30/50 | Train Loss: 0.0024, Train Acc: 99.89% | Test Loss: 0.0042, Test Acc: 99.43%
# Epoch 31/50 | Train Loss: 0.0023, Train Acc: 99.91% | Test Loss: 0.0040, Test Acc: 99.45%
# Epoch 32/50 | Train Loss: 0.0022, Train Acc: 99.91% | Test Loss: 0.0040, Test Acc: 99.47%
# Epoch 33/50 | Train Loss: 0.0022, Train Acc: 99.91% | Test Loss: 0.0039, Test Acc: 99.45%
# Epoch 34/50 | Train Loss: 0.0021, Train Acc: 99.91% | Test Loss: 0.0039, Test Acc: 99.51%
# Epoch 35/50 | Train Loss: 0.0021, Train Acc: 99.92% | Test Loss: 0.0039, Test Acc: 99.51%
# Epoch 36/50 | Train Loss: 0.0020, Train Acc: 99.92% | Test Loss: 0.0039, Test Acc: 99.49%
# Epoch 37/50 | Train Loss: 0.0020, Train Acc: 99.92% | Test Loss: 0.0038, Test Acc: 99.47%
# Epoch 38/50 | Train Loss: 0.0019, Train Acc: 99.93% | Test Loss: 0.0038, Test Acc: 99.49%
# Epoch 39/50 | Train Loss: 0.0019, Train Acc: 99.93% | Test Loss: 0.0037, Test Acc: 99.53%
# Epoch 40/50 | Train Loss: 0.0018, Train Acc: 99.93% | Test Loss: 0.0037, Test Acc: 99.51%
# Epoch 41/50 | Train Loss: 0.0018, Train Acc: 99.93% | Test Loss: 0.0037, Test Acc: 99.47%
# Epoch 42/50 | Train Loss: 0.0017, Train Acc: 99.94% | Test Loss: 0.0037, Test Acc: 99.49%
# Epoch 43/50 | Train Loss: 0.0017, Train Acc: 99.93% | Test Loss: 0.0037, Test Acc: 99.51%
# Epoch 44/50 | Train Loss: 0.0016, Train Acc: 99.94% | Test Loss: 0.0037, Test Acc: 99.47%
# Epoch 45/50 | Train Loss: 0.0016, Train Acc: 99.95% | Test Loss: 0.0036, Test Acc: 99.49%
# Epoch 46/50 | Train Loss: 0.0016, Train Acc: 99.95% | Test Loss: 0.0036, Test Acc: 99.49%
# Epoch 47/50 | Train Loss: 0.0015, Train Acc: 99.95% | Test Loss: 0.0036, Test Acc: 99.51%
# Epoch 48/50 | Train Loss: 0.0015, Train Acc: 99.95% | Test Loss: 0.0035, Test Acc: 99.53%
# Epoch 49/50 | Train Loss: 0.0015, Train Acc: 99.95% | Test Loss: 0.0034, Test Acc: 99.55%
# Epoch 50/50 | Train Loss: 0.0014, Train Acc: 99.95% | Test Loss: 0.0035, Test Acc: 99.49%

# %%
plt.plot(train_losses_ce, label='Train CE')
plt.plot(test_losses_ce, label='Test CE')
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Loss vs Epochs for Different Loss Functions")
plt.legend()
plt.show()

# %%
plt.plot(train_losses_mse, label='Train MSE')
plt.plot(test_losses_mse, label='Test MSE')
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Loss vs Epochs for Different Loss Functions")
plt.legend()
plt.show()

# %%
plt.plot(train_acc_ce, label='Train CE')
plt.plot(test_acc_ce, label='Test CE')
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Accuracy vs Epochs for Different Loss Functions")
plt.legend()
plt.show()

# %%
plt.plot(train_acc_mse, label='Train MSE')
plt.plot(test_acc_mse, label='Test MSE')
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Accuracy vs Epochs for Different Loss Functions")
plt.legend()
plt.show()
